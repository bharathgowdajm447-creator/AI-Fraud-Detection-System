# %%
import pandas as pd
import joblib

# %%
deployment_features = [
    "TransactionAmt",
    "card1",
    "card2",
    "card6",
    "card1_frequency",
    "email_frequency"
]

deployment_features
# Out:
# ['TransactionAmt',
#  'card1',
#  'card2',
#  'card6',
#  'card1_frequency',
#  'email_frequency']

# %%
import os

print(os.getcwd())
# Out:
# c:\CP2\notebooks

# %%
joblib.dump(
    deployment_features,
    "../deployment/deployment_features.pkl"
)
# Out:
# ['../deployment/deployment_features.pkl']

# %%
import os

os.makedirs("deployment", exist_ok=True)

print("Deployment folder ready")
# Out:
# Deployment folder ready

# %%
import joblib

joblib.dump(
    deployment_features,
    "deployment/deployment_features.pkl"
)

print("Saved successfully")
# Out:
# Saved successfully

# %%
import os

os.listdir("deployment")
# Out:
# ['deployment_features.pkl']

# %%
import os

print(os.getcwd())
# Out:
# c:\CP2\notebooks

# %%
import os

os.path.exists("../deployment")
# Out:
# True

# %%
import joblib

joblib.dump(
    deployment_features,
    "../deployment/deployment_features.pkl"
)

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
import joblib

joblib.dump(
    deployment_features,
    "../deployment/deployment_features.pkl"
)

print("Saved Successfully")
# Out:
# Saved Successfully

# %%
import os

os.listdir("../deployment")
# Out:
# ['deployment_features.pkl']
